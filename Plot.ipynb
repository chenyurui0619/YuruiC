# %% [markdown]
# <a href="https://colab.research.google.com/github/chenyurui0619/YuruiC/blob/master/Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
mf = pd.read_csv('/content/drive/My Drive/Colab Notebooks/mid_velocity.csv', delimiter=',')
sf = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Steady_Velocity.csv', delimiter=',')

# %%
sf
# Out:
#         Y_15      V_15      Y_30  ...       V_0          Z     V_Z
# 0   1.999500   0.00000  1.999100  ...   0.00000  29.657000  15.959
# 1   1.999400   0.00000  1.998400  ...   1.02600  28.802000  16.138
# 2   1.999300   0.00000  1.955100  ...   2.18770  28.442000  15.991
# 3   1.951800   0.84213  1.946100  ...   3.52670  27.946000  15.978
# 4   1.944700   1.02000  1.900900  ...   5.13020  27.067000  15.979
# 5   1.937300   1.01890  1.879900  ...   7.15360  25.575000  15.827
# 6   1.892300   1.87330  1.833300  ...   7.85670  24.076000  16.001
# 7   1.876200   2.21910  1.821600  ...   7.95030  23.582000  15.904
# 8   1.859700   2.25980  1.797100  ...   8.42310  23.004000  16.018
# 9   1.817900   3.10740  1.748700  ...   9.87190  22.631000  15.916
# 10  1.790600   3.58980  1.732000  ...  10.08800  22.091000  15.895
# 11  1.762700   3.74120  1.693600  ...  10.50700  20.980000  15.962
# 12  1.724900   4.52520  1.433600  ...  11.07100  19.583000  15.873
# ...

# %%
x = sf['Y_15']
y = sf['V_15']

# %%
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

# %%
m = np.linspace(-2, 2, 100)
# the function
n = 15.92 * (1-(m/2)**2)

# %%
fig = plt.scatter(x, y)
fig = plt.plot(m, n, 'red')
plt.xlabel('Y_point by diameter(cm)')
plt.ylabel('Velocity through pipe(cm/s)')
# Out:
# Text(0, 0.5, 'Velocity through pipe(cm/s)')

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_trisurf(x,y,z, color='white', edgecolors='grey', alpha=0.5)
ax.scatter(x, y, z, c='red')
plt.show()
